# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LassoCV
from xgboost import XGBRegressor

# %% [markdown]
# ---
# ---
#
# # 0. UTILITIES

# %%
start_date = '2015-07-01'
end_date = '2016-06-30'

# Generate a range of dates
date_range = pd.date_range(start=start_date, end=end_date).astype(str).to_list()

date_frame = pd.DataFrame(date_range,columns=['Date'])

date_frame['Month'] = date_frame['Date'].apply(lambda x: int(x.split("-")[1]))
date_frame['Year'] = date_frame['Date'].apply(lambda x: int(x.split("-")[0]))

# %% [markdown]
# ---
# ---
#
# # 1. CLEANING

# %%
sales = pd.read_csv('data/raw/Sales.csv',sep='\t', low_memory=False)

# %%
sales['price'] = sales['MRP']
sales['Date'] = sales['Date'].apply(lambda x: datetime.datetime.strptime(x, "%d-%m-%Y %H:%M").strftime("%Y-%m-%d"))

sales = sales[['Date','Analytic_Category','Units_sold','price']]

# %%
# aggregate sales

aggregated_sales = sales.groupby(['Date', 'Analytic_Category']).agg(
    Units_sold=('Units_sold', 'sum'),
    price=('price', 'sum')
).reset_index().rename({'price':'revenue'}, axis=1)

# %%
# explicitly write all dates and categories, with 0 where no sales took place

categories = sales['Analytic_Category'].unique()

all_combinations = pd.MultiIndex.from_product([date_range, categories], names=['Date', 'Analytic_Category'])
full_df = pd.DataFrame(index=all_combinations).reset_index()

aggregated_sales = full_df.merge(aggregated_sales, on=['Date','Analytic_Category'], how='left')

aggregated_sales['Units_sold'] = aggregated_sales['Units_sold'].fillna(0).astype(int)
aggregated_sales['revenue'] = aggregated_sales['revenue'].fillna(0).astype(float)

# %%
aggregated_sales
# Out:
#             Date   Analytic_Category  Units_sold  revenue
# 0     2015-07-01     CameraAccessory           0      0.0
# 1     2015-07-01      GamingHardware           0      0.0
# 2     2015-07-01  EntertainmentSmall           0      0.0
# 3     2015-07-01           GameCDDVD           0      0.0
# 4     2015-07-01              Camera           0      0.0
# ...          ...                 ...         ...      ...
# 1825  2016-06-30     CameraAccessory           0      0.0
# 1826  2016-06-30      GamingHardware           0      0.0
# 1827  2016-06-30  EntertainmentSmall           0      0.0
# 1828  2016-06-30           GameCDDVD           0      0.0
# 1829  2016-06-30              Camera           0      0.0
#
# [1830 rows x 4 columns]

# %%
# get total sales

total_sales = aggregated_sales.groupby('Date').agg(
            Analytic_Category=('Analytic_Category','first'),
            Units_sold=('Units_sold','sum'),
            revenue=('revenue','sum')
        ).reset_index()

# %%
total_sales['Analytic_Category'] = 'total'

# %%
sales = pd.concat([total_sales,aggregated_sales]).sort_values('Date')

# %% [markdown]
# ---

# %%
media = pd.read_csv('data/raw/MediaInvestment.csv')

# %%
media = media.fillna(0.0)

# %%
n_days = date_frame[['Month','Date']].groupby("Month").count().reset_index()

# %%
media = media.merge(n_days,on='Month').rename({'Date':'Days'},axis=1)

# %%
media.iloc[:,2:-1] = media.iloc[:,2:-1].div(media['Days'],axis=0)

# %%
media = date_frame.merge(media,on=['Month','Year'], how='left').drop(['Month','Year','Days'],axis=1)

# %% [markdown]
# ---

# %%
nps = pd.read_csv('data/raw/MonthlyNPSscore.csv')

# %%
nps['Year'] = nps['Date'].apply(lambda x: int(x.split('/')[2]))
nps['Month']= nps['Date'].apply(lambda x: int(x.split('/')[0]))
nps = nps.drop('Date',axis=1)

# %%
nps = date_frame.merge(nps,on=['Year','Month'],how='left').drop(['Year','Month'],axis=1)

# %% [markdown]
# ---
# ---
#
# # 2. Feature Engineering

# %%
features = media.merge(nps,on='Date').drop('Total Investment',axis=1)

# %% [markdown]
# ---
#
# ### Adstock

# %%
def adstock_transform(series, decay):
    """Apply Adstock transformation to a media spend series."""
    adstocked = np.zeros(len(series))
    for i in range(1, len(series)):
        adstocked[i] = series[i] + decay * adstocked[i-1]
    return adstocked

# %%
features_adstock = features.copy()

for col in features.columns[2:]:
    features_adstock[col] = adstock_transform(features[col],0.8)

# %% [markdown]
# ---
#
# ### Saturation

# %%
def hill_function(spend, theta, s):
    return (spend**s) / (spend**s + theta**s)

# %%
features_saturation = features_adstock.copy()

for col in features.columns[2:-1]:
    theta = features[col].mean() + features[col].std()
    features_saturation[col] = hill_function(features_adstock[col], theta, 1.5)

# %%
features = features_saturation

# %% [markdown]
# ---
# ---
#
# # 3. Regression

# %%
target = sales.query('Analytic_Category == "total"')[['Date','Units_sold']]

# %%
split_ratio = 0.8
train_size = int(len(features) * split_ratio)

X_train = features.iloc[:train_size].drop('Date',axis=1)
X_test = features.iloc[train_size:].drop('Date',axis=1)

y_train = target.iloc[:train_size].drop('Date',axis=1)
y_test  = target.iloc[train_size:].drop('Date',axis=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ### Linear

# %%
# Ridge Regression
ridge = RidgeCV(alphas=np.logspace(-3, 3, 50), store_cv_values=True)
ridge.fit(X_train_scaled, y_train)

# Lasso Regression (for feature selection)
lasso = LassoCV(alphas=np.logspace(-3, 3, 50), max_iter=50000)
lasso.fit(X_train_scaled, y_train,)
# Out:
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:2341: FutureWarning: 'store_cv_values' is deprecated in version 1.5 and will be removed in 1.7. Use 'store_cv_results' instead.
#   warnings.warn(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134552980.92283487, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317098854.99231243, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 449194064.77362204, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 541763238.6535201, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 607782543.4931383, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 655885832.12169, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 691586905.4023533, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 718477471.8098781, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 738967906.5218215, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 754723327.7088268, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 766923733.7010734, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 776423472.2647123, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 783852316.759943, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 789681561.9712131, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 794267661.8202024, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 797883367.9074631, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 800738841.9335487, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 802996782.3104975, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 804784110.6132743, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\UY641FU\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 806199991.6087441, tolerance: 522713.61164999986
#   model = cd_fast.enet_coordinate_descent_gram(
# LassoCV(alphas=array([1.00000000e-03, 1.32571137e-03, 1.75751062e-03, 2.32995181e-03,
#        3.08884360e-03, 4.09491506e-03, 5.42867544e-03, 7.19685673e-03,
#        9.54095476e-03, 1.26485522e-02, 1.67683294e-02, 2.22299648e-02,
#        2.94705170e-02, 3.90693994e-02, 5.17947468e-02, 6.86648845e-02,
#        9.10298178e-02, 1.20679264e-01, 1.59985872e-01, 2.12095089e-01,
#        2.81176870e-01, 3.72759372e-0...
#        8.68511374e-01, 1.15139540e+00, 1.52641797e+00, 2.02358965e+00,
#        2.68269580e+00, 3.55648031e+00, 4.71486636e+00, 6.25055193e+00,
#        8.28642773e+00, 1.09854114e+01, 1.45634848e+01, 1.93069773e+01,
#        2.55954792e+01, 3.39322177e+01, 4.49843267e+01, 5.96362332e+01,
#        7.90604321e+01, 1.04811313e+02, 1.38949549e+02, 1.84206997e+02,
#        2.44205309e+02, 3.23745754e+02, 4.29193426e+02, 5.68986603e+02,
#        7.54312006e+02, 1.00000000e+03]),
#         max_iter=50000)

# %%
print(f"Ridge R²: {ridge.score(X_test_scaled, y_test)}")
print(f"Lasso R²: {lasso.score(X_test_scaled, y_test)}")
# Out:
# Ridge R²: -0.1740239525885694
# Lasso R²: 0.08290042489493532

# %% [markdown]
# ---
#
# ### XGBoost

# %%
xgb = XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=5)
xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)
r2_xgb = r2_score(y_test, y_pred_xgb)
print(f"XGBoost R²: {r2_xgb:.4f}")
# Out:
# XGBoost R²: -0.7347
